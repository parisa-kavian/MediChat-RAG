# %% [markdown]
# <a href="https://colab.research.google.com/github/parisa-kavian/MediChat-RAG/blob/main/MedicChat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MediChat-RAG
#
# A **Retrieval-Augmented Generation (RAG)** medical Q&A assistant grounded in authoritative **Mayo Clinic** articles, powered by `gpt-4o-mini`.
#
# The notebook builds one ingestion + retrieval pipeline and then exposes it in two modes:
#
# | Mode | Behaviour |
# | --- | --- |
# | **Stateless** | Each question answered independently |
# | **Stateful** | Keeps the last few turns for follow-ups and pronoun resolution |
#
# > **Disclaimer.** This is a technical demonstration of retrieval over public health articles. It is **not** medical advice and must not be used for diagnosis or treatment.

# %% [markdown]
# ## 1 · Setup

# %%
# %%capture
# !pip install -U langchain langchain-openai langchain-community langchain-text-splitters faiss-cpu tiktoken beautifulsoup4 lxml pandas

# %%
import getpass
import os

# Read the key securely at runtime - never hard-code it in the notebook.
if not os.environ.get("OPENAI_API_KEY"):
    os.environ["OPENAI_API_KEY"] = getpass.getpass("Enter your OpenAI API key: ")

# %% [markdown]
# ## 2 · Build the knowledge base (once)
#
# Scrape a curated set of Mayo Clinic pages, clean the HTML, chunk it, embed it, and build a FAISS index.
# The index is cached locally so re-running the notebook does not re-scrape or re-embed.

# %%
from langchain_community.document_loaders import AsyncHtmlLoader
from langchain_community.document_transformers import BeautifulSoupTransformer
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import FAISS
from langchain_openai import OpenAIEmbeddings

INDEX_DIR = "mayoclinic_faiss"   # local, relative path (works anywhere)

URLS = [
    "https://www.mayoclinic.org/diseases-conditions/heart-disease/symptoms-causes/syc-20353118",
    "https://www.mayoclinic.org/diseases-conditions/cancer/symptoms-causes/syc-20370588",
    "https://www.mayoclinic.org/diseases-conditions/diabetes/symptoms-causes/syc-20371444",
    "https://www.mayoclinic.org/healthy-lifestyle/nutrition-and-healthy-eating/in-depth/healthy-diets/art-20045016",
    "https://www.mayoclinic.org/diseases-conditions/high-blood-pressure/symptoms-causes/syc-20373410",
]

embeddings = OpenAIEmbeddings()

if os.path.isdir(INDEX_DIR):
    vectorstore = FAISS.load_local(INDEX_DIR, embeddings, allow_dangerous_deserialization=True)
    print(f"Loaded cached FAISS index from ./{INDEX_DIR}")
else:
    docs = AsyncHtmlLoader(URLS).load()
    docs_clean = BeautifulSoupTransformer().transform_documents(
        docs, tags_to_extract=["p", "li", "div", "article"]
    )
    chunks = RecursiveCharacterTextSplitter(
        chunk_size=1000, chunk_overlap=200, length_function=len
    ).split_documents(docs_clean)
    print(f"Scraped {len(docs)} pages -> {len(chunks)} chunks")

    vectorstore = FAISS.from_documents(chunks, embeddings)
    vectorstore.save_local(INDEX_DIR)
    print(f"Built and cached FAISS index at ./{INDEX_DIR}")

retriever = vectorstore.as_retriever(search_kwargs={"k": 3})

# %% [markdown]
# ## 3 · Shared LLM + RAG chain (LCEL)

# %%
from operator import itemgetter
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_core.runnables import RunnableParallel, RunnablePassthrough
from langchain_core.output_parsers import StrOutputParser

llm = ChatOpenAI(model="gpt-4o-mini", temperature=0.2)

prompt = ChatPromptTemplate.from_messages([
    ("system",
     "You are a helpful medical assistant. Answer using only the reliable context below, "
     "and refer to earlier turns when relevant. Always advise the user to consult a doctor "
     "for personalized advice.\n\nContext:\n{context}"),
    MessagesPlaceholder(variable_name="chat_history"),
    ("human", "{question}"),
])

def format_docs(docs):
    return "\n\n".join(d.page_content for d in docs)

rag_chain = (
    RunnableParallel({
        "context": itemgetter("question") | retriever | format_docs,
        "question": itemgetter("question"),
        "chat_history": lambda x: x.get("chat_history", []),
    })
    | prompt
    | llm
    | StrOutputParser()
)

# %% [markdown]
# ## 4 · Stateless mode
# Each question is answered independently (empty history).

# %%
from langchain_community.callbacks import get_openai_callback

def ask(question: str) -> str:
    with get_openai_callback() as cb:
        answer = rag_chain.invoke({"question": question, "chat_history": []})
    print("Question:", question)
    print("Answer:", answer)
    print(f"[tokens: {cb.total_tokens} | cost: ${cb.total_cost:.5f}]")
    print("-" * 60)
    return answer

_ = ask("What are the common symptoms and causes of heart disease?")

# %% [markdown]
# ## 5 · Stateful mode
# Keeps the last 4 messages (2 turns) as context, so follow-ups with pronouns ("it", "its") resolve correctly.

# %%
from langchain_core.messages import HumanMessage, AIMessage

MAX_HISTORY_MESSAGES = 4
chat_history: list = []

def ask_with_memory(question: str) -> None:
    global chat_history
    with get_openai_callback() as cb:
        answer = rag_chain.invoke({
            "question": question,
            "chat_history": chat_history[-MAX_HISTORY_MESSAGES:],
        })
    chat_history += [HumanMessage(content=question), AIMessage(content=answer)]
    print("Question:", question)
    print("Answer:", answer)
    print("-" * 60)

conversation = [
    "What are the common symptoms of heart disease?",
    "What lifestyle changes can help prevent it?",
    "Can you explain more about how diet affects it?",
    "How does high blood pressure relate to the heart disease symptoms we discussed earlier?",
]

for q in conversation:
    ask_with_memory(q)
